# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # here we go

# %%
x = np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y)
plt.plot(x,np.cos(x),color='red')
plt.plot(x,np.cos(x-np.pi/4),color='black')
plt.plot(x,np.cos(x+np.pi/4),color='green')
plt.plot(x,np.log(x),color='blue')
#plt.plot(x,x**2,color='purple')
# Out:
# /Users/jteitelbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
y=10
