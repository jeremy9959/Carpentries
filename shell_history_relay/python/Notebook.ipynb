# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # here we go

# %%
x = np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y)
plt.plot(x,np.cos(x),color='gray')
#plt.plot(x,np.cos(x-np.pi/4),color='black')
#plt.plot(x,np.cos(x+np.pi/4),color='orange')
plt.plot(x,np.log(x),color='blue')
#plt.plot(x,x**2,color='purple')
# Out:
# /home/jet08013/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
y=10

# %%
x=np.linspace(1,100,1000)
y = 1/(1+x**2)

# %%
plt.plot(x,y)
